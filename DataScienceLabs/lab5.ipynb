# %% [markdown]
# <center><h1> Uvod u podatkovnu znanost  </h1></center>
# <center><h2> Zimski semestar - 2023 </h2></center>
# <center><h3> Lab 5</h3></center>
# <center><h3> </h3></center>
# <center><h3> Vizualizacija podataka 2</h3></center>

# %% [markdown]
# Ovo je vježba o vizualizaciji podataka! Koristit će se uobičajene python biblioteke, Matplotlib i Seaborn za stvaranje učinkovitih i jasnih vizualizacija. Radit ćete na skupu podataka koji sadrži informacije o deset filmova s najvećom zaradom svake godine.
#
# Ovo su vizualizacije koje će se napraviti, a koje ćete koristiti za rješavanje vježbe:
# - [Histogram](https://matplotlib.org/3.3.1/api/_as_gen/matplotlib.pyplot.hist.html)
# - [Boxplot](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.boxplot.html)
# - [Scatterplot](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html)
# - [Plot](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html)
# - [Jointplot](https://seaborn.pydata.org/generated/seaborn.jointplot.html)
# - [Barplot](https://seaborn.pydata.org/generated/seaborn.barplot.html)
# - [Violinplot](https://seaborn.pydata.org/generated/seaborn.violinplot.html)
# - [Errorbar](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.errorbar.html)
# - [Filled plot](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.fill_between.html)
# - [Panels](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplots.html)
# - [Heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html)
#
# Osim Matplotliba i Searbona, postoji mnogo više resursa koji bi vam mogli biti korisni, na primjer:
# - [ggplot](http://ggplot.yhathq.com/)
# - [plotly](https://plotly.com/python/)
# - [Geopy](https://geopy.readthedocs.io/en/stable/) te [Folium](https://python-visualization.github.io/folium/)

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from seaborn) (2.1.2)
# Requirement already satisfied: pandas>=1.2 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/andrijabotica/Desktop/data-science-course/virtual/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys, re
import seaborn as sns

episodes = pd.read_csv('simpsons_episodes.csv')
episodes
# Out:
#       id                                              title original_air_date  \
# 0     10                                  Homer's Night Out        1990-03-25
# 1     12                                 Krusty Gets Busted        1990-04-29
# 2     14                                   Bart Gets an "F"        1990-10-11
# 3     17  Two Cars in Every Garage and Three Eyes on Eve...        1990-11-01
# 4     19                               Dead Putting Society        1990-11-15
# ..   ...                                                ...               ...
# 595  500                                 At Long Last Leave        2012-02-19
# 596  502                              How I Wet Your Mother        2012-03-11
# 597  511                         Adventures in Baby-Getting        2012-11-04
# 598  542                                              Diggs        2014-03-09
# 599  548                              Days of Future Future        2014-04-13
#
#     production_code  season  number_in_season  number_in_series  \
# 0              7G10       1                10                10
# 1              7G12       1                12                12
# 2              7F03       2                 1                14
# 3              7F01       2                 4                17
# 4              7F08       2                 6                19
# ..              ...     ...               ...               ...
# 595          PABF07      23                14               500
# 596          PABF08      23                16               502
# 597          PABF18      24                 3               511
# 598          SABF08      25                12               542
# 599          SABF13      25                18               548
#
#      us_viewers_in_millions    views  imdb_rating  imdb_votes  \
# 0                     30.30  50816.0          7.4      1511.0
# 1                     30.40  62561.0          8.3      1716.0
# 2                     33.60  59575.0          8.2      1638.0
# 3                     26.10  64959.0          8.1      1457.0
# 4                     25.40  50691.0          8.0      1366.0
# ..                      ...      ...          ...         ...
# 595                    5.77  45226.0          7.0       580.0
# 596                    4.97  44818.0          7.3       541.0
# 597                    5.65  39687.0          6.9       460.0
# 598                    2.69  39292.0          6.4       473.0
# 599                    3.64  55742.0          7.0       504.0
#
#                                              image_url  \
# 0    http://static-media.fxx.com/img/FX_Networks_-_...
# 1    http://static-media.fxx.com/img/FX_Networks_-_...
# 2    http://static-media.fxx.com/img/FX_Networks_-_...
# 3    http://static-media.fxx.com/img/FX_Networks_-_...
# 4    http://static-media.fxx.com/img/FX_Networks_-_...
# ..                                                 ...
# 595  http://static-media.fxx.com/img/FX_Networks_-_...
# 596  http://static-media.fxx.com/img/FX_Networks_-_...
# 597  http://static-media.fxx.com/img/FX_Networks_-_...
# 598  http://static-media.fxx.com/img/FX_Networks_-_...
# 599  http://static-media.fxx.com/img/FX_Networks_-_...
#
#                                            video_url
# 0    http://www.simpsonsworld.com/video/275197507879
# 1    http://www.simpsonsworld.com/video/288019523914
# 2    http://www.simpsonsworld.com/video/260539459671
# 3    http://www.simpsonsworld.com/video/260537411822
# 4    http://www.simpsonsworld.com/video/260539459670
# ..                                               ...
# 595  http://www.simpsonsworld.com/video/230541891832
# 596  http://www.simpsonsworld.com/video/230597187582
# 597  http://www.simpsonsworld.com/video/221688899646
# 598  http://www.simpsonsworld.com/video/310529091639
# 599  http://www.simpsonsworld.com/video/310257731892
#
# [600 rows x 13 columns]

# %%
# extract some datetime variables
episodes['datetime'] = pd.to_datetime(episodes['original_air_date'])
episodes['datetime_year'] = episodes['datetime'].dt.year
episodes['datetime_month'] =episodes['datetime'].dt.month
episodes['datetime_day'] =episodes['datetime'].dt.day
episodes['datetime-MM-DD'] = episodes['datetime'].dt.strftime('%m-%d')

# %% [markdown]
# # 1. Tutorial: Korištenje biblioteke za vizualizaciju podataka

# %% [markdown]
# Koristit će se dataset blockbustera. Sažetak feature-a:
#
# - *title*: Episode title
# - *original_air_date*
# - *production_code*
# - *season*
# - *number_in_season*
# - *number_in_series*
# - *us_viewers_in_millions*
# - *views*
# - *imdb_rating*
# - *imdb_votes*
# - *image_url*
# - *video_url*

# %% [markdown]
# ## Vizualizacija dviju kontinuiranih varijabli
#
# - Je li se smanjivao IMDB rating i US views kroz godine
# - Postoji mnogo načina kako se može ispitati odnos između dvije varijable. Najjednostavniji je dijagram scatterplot, koristeći plt.scatterplot()

# %%
plt.figure(figsize=(20, 7))
sns.scatterplot(data=episodes, x="datetime", y="imdb_rating", alpha=0.6)
plt.xlabel("Years")
plt.ylabel("IMDB rating")
# Out:
# Text(0, 0.5, 'IMDB rating')

# %% [markdown]
# ## Vizualizacija dviju varijabli, kontinuiranih i kategoričkih
#
# - Razmotrimo IMDB rating i US views kroz godine i sezone emitiranja
# - Prikazat ćemo barplot, boxplot i violinplot. Seaborn nudi mnogo više uvjerljivih vizualizacija. Bacite oko na primjere: https://seaborn.pydata.org/examples/index.html

# %%
# barplot
fig, ax1 = plt.subplots(figsize=(20,7))

sns.barplot(data=episodes, x="datetime_year", y="imdb_rating", color="skyblue")
ax1.set_xlabel("Year")
ax1.set_ylabel("IMDB")
ax1.tick_params(axis="y", labelcolor="skyblue")

ax2 = ax1.twinx()
sns.barplot(data=episodes, x="datetime_year", y="views", color="orange")
ax2.set_xlabel("Year")
ax2.set_ylabel("US views")
ax2.tick_params(axis="y", labelcolor="orange")

fig, ax3 = plt.subplots(figsize=(20,7))

sns.barplot(data=episodes, x="season", y="imdb_rating", color="lightgreen")
ax3.set_xlabel("Seasons")
ax3.set_ylabel("IMDB")
ax3.tick_params(axis="y", labelcolor="lightgreen")

ax4 = ax3.twinx()
sns.barplot(data=episodes, x="season", y="views", color="purple")
ax4.set_xlabel("Seasons")
ax4.set_ylabel("US views")
ax4.tick_params(axis="y", labelcolor="purple")

# %%
# barplot
fig, ax1 = plt.subplots(figsize=(20,7))

sns.boxplot(data=episodes, x="datetime_year", y="imdb_rating", color="skyblue")
ax1.set_xlabel("Year")
ax1.set_ylabel("IMDB")
ax1.tick_params(axis="y", labelcolor="skyblue")

ax2 = ax1.twinx()
sns.boxplot(data=episodes, x="datetime_year", y="views", color="orange")
ax2.set_xlabel("Year")
ax2.set_ylabel("US views")
ax2.tick_params(axis="y", labelcolor="orange")

fig, ax3 = plt.subplots(figsize=(20,7))

sns.boxplot(data=episodes, x="season", y="imdb_rating", color="lightgreen")
ax3.set_xlabel("Seasons")
ax3.set_ylabel("IMDB")
ax3.tick_params(axis="y", labelcolor="lightgreen")

ax4 = ax3.twinx()
sns.boxplot(data=episodes, x="season", y="views", color="purple")
ax4.set_xlabel("Seasons")
ax4.set_ylabel("US views")
ax4.tick_params(axis="y", labelcolor="purple")

# %%
# violinplot
# barplot
fig, ax1 = plt.subplots(figsize=(20,7))

sns.violinplot(data=episodes, x="datetime_year", y="imdb_rating", color="skyblue")
ax1.set_xlabel("Year")
ax1.set_ylabel("IMDB")
ax1.tick_params(axis="y", labelcolor="skyblue")

ax2 = ax1.twinx()
sns.violinplot(data=episodes, x="datetime_year", y="views", color="orange")
ax2.set_xlabel("Year")
ax2.set_ylabel("US views")
ax2.tick_params(axis="y", labelcolor="orange")

fig, ax3 = plt.subplots(figsize=(20,7))

sns.violinplot(data=episodes, x="season", y="imdb_rating", color="lightgreen")
ax3.set_xlabel("Seasons")
ax3.set_ylabel("IMDB")
ax3.tick_params(axis="y", labelcolor="lightgreen")

ax4 = ax3.twinx()
sns.violinplot(data=episodes, x="season", y="views", color="purple")
ax4.set_xlabel("Seasons")
ax4.set_ylabel("US views")
ax4.tick_params(axis="y", labelcolor="purple")

# %% [markdown]
# # 2. Vježbe: Izrada naprednijih vizualizacija
#
# Da bismo napravili dobru vizualizaciju podataka, prvo trebamo imati jasnu ideju o tome što želimo vizualizirati! Objedinjujemo li podatke i kako? Koja bi količina trebala biti na različitim osima? Kako koristiti boje i veličine predmeta? Često pomaže ručno skicirati vizualizaciju prije nego što je kodirate.
#
# U sljedećoj vježbi dobit ćete opise vizualizacija koje bi mogle biti korisne za razumijevanje skupa podataka o filmovima.

# %% [markdown]
# ## 2.1 Heatmape
#
# - Vizualizirajte IMDB i US views kroz sezone te koristite funkciju Seaborn heatmap te funkciju *pivot* of pandasa
#
# - Konačno, heatmapom možemo predstaviti tri varijable, kodiranjem treće varijable bojom. Pokažite kako sa sezonom opada IMDB ocjena i US views korištenjem heatmape

# %%
# Napišite svoj kod ovdje da biste kreirali prvu heatmapu

data_matrix = episodes.pivot_table(index='number_in_season', columns='season', values='imdb_rating')
data_matrix

plt.figure(figsize=(14, 10))
sns.heatmap(data_matrix, annot=True, cmap='Blues', fmt='.1f', linewidth='.5', linecolor='white', cbar_kws={'label': 'IMDB Rating'})

plt.title('IMDB Rating per Episode', fontsize=16)
plt.xlabel('Season', fontsize=12)
plt.ylabel('Episode Number in Season', fontsize=12)

plt.tight_layout()
plt.show()

# %%
# Napišite svoj kod ovdje da biste kreirali drugu heatmapu
data_matrix = episodes.pivot_table(index='number_in_season', columns='season', values='us_viewers_in_millions')
data_matrix

plt.figure(figsize=(14, 10))
sns.heatmap(data_matrix, annot=True, cmap='Blues', fmt='.1f', linewidth='0.7', linecolor='gray', cbar_kws={'label': 'US viewers in millions'})

plt.title('US viewers per episodes', fontsize=16)
plt.xlabel('Season', fontsize=12)
plt.ylabel('US viewers', fontsize=12)

plt.tight_layout()
plt.show()
